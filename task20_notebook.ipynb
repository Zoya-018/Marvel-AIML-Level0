# %% [markdown]
# # Notebook Ninja – Getting Started with Jupyter

# %% [markdown]
# ## Introduction
# Jupyter Notebook helps us combine code and explanation in one place. It is useful for writing clean and structured work.

# %% [markdown]
# # Notebook Ninja – Getting Started with Jupyter
#
# ## Things I Want to Learn
# - Writing clean notebooks
# - Creating graphs
# - Combining code and explanation
#
# ## Text Formatting
# This is **bold text**
# This is *italic text*
#
# ---
#
# ## Image
# ![Jupyter Logo](https://jupyter.org/assets/homepage/main-logo.svg)
#
# ## Code Snippet
# ```python
# print("Hello, Jupyter!")
# ```

# %%
a = 10
b = 20

result = a + b
print("Result:", result)
# Out:
# Result: 30

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 4, 6, 8]

plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Graph")
plt.show()

# %% [markdown]
# ## Conclusion
# This notebook helped me understand how to use Markdown, write Python code, and create graphs in Jupyter Notebook.

# %% [markdown]
# This task improved my understanding of how Jupyter Notebook can be used for both coding and documentation.
